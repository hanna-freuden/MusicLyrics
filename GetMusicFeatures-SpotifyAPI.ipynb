# %% [markdown]
# # Get music features from Spotify API for Billboard Top 100 songs

# %% [markdown]
# In this notebook, ([lyrics data of Billboard Top100 songs between 1964 and 2015](https://github.com/walkerkq/musiclyrics)) is used. Each song is matched with musical features from [Spotify API](https://developer.spotify.com/), containing 12 audio features for each track (including acousticness, liveness, speechiness and instrumentalness, energy, loudness, danceability valence, duration, tempo, key, and mode).

# %%
#import libraries
import pandas as pd
import numpy as np
import collections
import re
import sys
import time
from nltk.tokenize import word_tokenize
#!pip install wordninja
import wordninja

# %%
#load billboard songs and lyrics from github.com/walkerkq
file_path="https://github.com/walkerkq/musiclyrics/blob/master/billboard_lyrics_1964-2015.csv"
df = pd.read_csv(file_path,delimiter=',', encoding='latin-1')

# %%
df.columns
# Out:
# Index(['Rank', 'Song', 'Artist', 'Year', 'Lyrics', 'Source'], dtype='object')

# %%
#get list of artists
artists=df['Artist'].to_list()

# %% [markdown]
# ## 1. Data Cleaning
# Cleaning of artist and song names needs to be done in order to find the songs' musical features using the Spotify API

# %% [markdown]
# ### Clean artist names

# %%
#remove featuring artists
artists_clean=[]
for artist in artists:
    a_string=artist
    search_string=' featuring '
    if search_string not in a_string:
            artists_clean.append(a_string)
    else:
        split_string = a_string.split(search_string, 1)
        substring = split_string[0]
        artists_clean.append(substring)
len(artists_clean)
# Out:
# 5100

# %%
#for each artist string, evaluate if string is containted in other string and replace longer by shorter string
# this eliminates remaining featured artists that will cause errors when looking up the song in Spotify API

for i in range(len(artists_clean)):
    target_string=artists_clean[i]
    for search_string in artists_clean:
        if target_string==search_string:
            pass
        else:
            if len(search_string)>3 and target_string.find(" "+search_string+" ")!=-1:
                artists_clean[i]=search_string
            else:
                pass
                

            
len(artists_clean)
# Out:
# 5100

# %%
#append artists_clean column to data frame containing billboard songs, ranks and lyrics
df['Artists clean']=artists_clean

# %%
#make list of artist-tracks for billboard songs
songs=df['Artists clean']+" " +df['Song']
print(len(songs))
# Out:
# 5100

# %%
#assign to artist_song1
df['artist_song1']=songs

# %% [markdown]
# ### Clean song names

# %%
#titles may be messy and have words crunched together
#wordninja is a package that allows to robabilistically split concatenated words using NLP based on English Wikipedia unigram frequencies.
#Reference: https://github.com/keredson/wordninja

#make alternative title with wordninja package for songs that cannot be found
#split words into individual syllables/words to be able to find them on spotify
songs_clean=[]
for song in df.Song :
    string=wordninja.split(song)
    title=""
    for s in string:
        title+=s+" " 
    songs_clean.append(title.strip())

# %%
df['songs_clean']=songs_clean
songs2=df['Artists clean']+" " +df['songs_clean']
df['artist_song2']=songs2

# %% [markdown]
# ## 2. Retrieve musical features from Spotify API

# %%
#connect to spotify api
import requests
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
from tqdm import notebook
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
AUTH_URL = 'https://accounts.spotify.com/api/token'
CLIENT_ID = ''
CLIENT_SECRET = ''

auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

BASE_URL = 'https://api.spotify.com/v1/'
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

# %%
df.head()
# Out:
#    Rank                                      Song  \
# 0     1                               wooly bully
# 1     2  i cant help myself sugar pie honey bunch
# 2     3                i cant get no satisfaction
# 3     4                       you were on my mind
# 4     5              youve lost that lovin feelin
#
#                           Artist  Year  \
# 0  sam the sham and the pharaohs  1965
# 1                      four tops  1965
# 2             the rolling stones  1965
# 3                        we five  1965
# 4         the righteous brothers  1965
#
#                                               Lyrics  Source  \
# 0  sam the sham miscellaneous wooly bully wooly b...     3.0
# 1   sugar pie honey bunch you know that i love yo...     1.0
# 2                                                        1.0
# 3   when i woke up this morning you were on my mi...     1.0
# 4   you never close your eyes anymore when i kiss...     1.0
#
#                    Artists clean  \
# 0  sam the sham and the pharaohs
# 1                      four tops
# 2             the rolling stones
# 3                        we five
# 4         the righteous brothers
#
#                                         artist_song1  \
# 0          sam the sham and the pharaohs wooly bully
# 1  four tops i cant help myself sugar pie honey b...
# 2      the rolling stones i cant get no satisfaction
# 3                        we five you were on my mind
# 4  the righteous brothers youve lost that lovin f...
#
#                                 songs_clean  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4            you ve lost that lovin feel in
#
#                                         artist_song2
# 0          sam the sham and the pharaohs wooly bully
# 1  four tops i cant help myself sugar pie honey b...
# 2      the rolling stones i cant get no satisfaction
# 3                        we five you were on my mind
# 4  the righteous brothers you ve lost that lovin ...

# %%
#function to retrieve track information
def get_tracks(df, col1, col2):
    tracks={}
    for i in notebook.tqdm(range(df.shape[0])):
        try:
            # Get the track URI (a unique ID) corresponding to track
            track_uri = sp.search(df[col1][i])['tracks']['items'][0]['uri']
            track_id=track_uri.replace("spotify:track:", "")
            #get artist corresponding to track
            artist=sp.search(df[col1][i])['tracks']['items'][0]['artists'][0]['name']
            r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)
            values=r.json()
            tracks[i]=values
        except:
            try:
                # Get the track URI (a unique ID) corresponding to track
                track_uri = sp.search(df[col2][i])['tracks']['items'][0]['uri']
                track_id=track_uri.replace("spotify:track:", "")
                #get artist corresponding to track
                artist=sp.search(df[col2][i])['tracks']['items'][0]['artists'][0]['name']
                r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)
                values=r.json()
                tracks[i]=values
            except:
                values={'danceability': '', 'energy': '', 'key': '', 'loudness': '', 'mode': '', 'speechiness': '', 'acousticness': '',   'instrumentalness': '',   'liveness': '',   'valence': '',   'tempo': '',   'type': '',   'id': '',   'uri': '',   'track_href': '',  'analysis_url': '',   'duration_ms': '',   'time_signature': ''}
                tracks[i]=values
        
    return tracks

# %%
#check for track info by first using songs and then songs cleaned
tracklist=get_tracks(df, 'artist_song1', 'artist_song2')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5100.0), HTML(value='')))

# %%
df_tracks=pd.DataFrame.from_dict(tracklist).T

# %%
df_tracks
# Out:
#      danceability energy key loudness mode speechiness acousticness  \
# 0           0.696  0.692   0   -9.586    1      0.0575        0.577
# 1           0.667  0.599   0   -8.894    1      0.0291        0.245
# 2           0.723  0.863   2    -7.89    1      0.0338       0.0383
# 3           0.507   0.56   1   -8.118    0      0.0473        0.554
# 4           0.369  0.305   1  -14.303    1      0.0267        0.522
# ...           ...    ...  ..      ...  ...         ...          ...
# 5095        0.608  0.628   8   -6.968    1       0.106        0.212
# 5096        0.706  0.572   8   -5.799    0      0.0326       0.0262
# 5097        0.672   0.52   8   -7.747    1      0.0353        0.859
# 5098        0.893   0.48   1   -3.728    0       0.356      0.00855
# 5099        0.673  0.859  11   -3.007    0       0.056      0.00426
#
#      instrumentalness liveness valence    tempo            type  \
# 0            0.000688    0.246   0.904  140.978  audio_features
# 1                   0    0.107   0.971  127.935  audio_features
# 2              0.0317    0.128   0.931  136.302  audio_features
# 3                   0   0.0517   0.645  143.259  audio_features
# 4                   0   0.0579   0.376   94.791  audio_features
# ...               ...      ...     ...      ...             ...
# 5095                0   0.0727   0.587  180.163  audio_features
# 5096                0    0.585   0.574  139.982  audio_features
# 5097                0    0.115    0.37  120.001  audio_features
# 5098                0    0.116   0.382   86.976  audio_features
# 5099            0.015    0.128   0.111  127.978  audio_features
#
#                           id                                   uri  \
# 0     0SRkuudTEWe2HOloI1Nssq  spotify:track:0SRkuudTEWe2HOloI1Nssq
# 1     6b6IMqP565TbtFFZg9iFf3  spotify:track:6b6IMqP565TbtFFZg9iFf3
# 2     2PzU4IB8Dr6mxV3lHuaG34  spotify:track:2PzU4IB8Dr6mxV3lHuaG34
# 3     36ckFm0oicmvX8bWEErIHd  spotify:track:36ckFm0oicmvX8bWEErIHd
# 4     6AeyHqzNHJthYJbn0tvJ4b  spotify:track:6AeyHqzNHJthYJbn0tvJ4b
# ...                      ...                                   ...
# 5095  6EYwUarLDfsZ0BMD3IYETF  spotify:track:6EYwUarLDfsZ0BMD3IYETF
# 5096  7seTcUFOhn5caSDbiSfsp0  spotify:track:7seTcUFOhn5caSDbiSfsp0
# 5097  5O2P9iiztwhomNh8xkR9lJ  spotify:track:5O2P9iiztwhomNh8xkR9lJ
# 5098  5lFDtgWsjRJu8fPOAyJIAK  spotify:track:5lFDtgWsjRJu8fPOAyJIAK
# 5099  6rMwYjoFvxKiaEH4If8ZpZ  spotify:track:6rMwYjoFvxKiaEH4If8ZpZ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0SRkuudTEWe2...
# 1     https://api.spotify.com/v1/tracks/6b6IMqP565Tb...
# 2     https://api.spotify.com/v1/tracks/2PzU4IB8Dr6m...
# 3     https://api.spotify.com/v1/tracks/36ckFm0oicmv...
# 4     https://api.spotify.com/v1/tracks/6AeyHqzNHJth...
# ...                                                 ...
# 5095  https://api.spotify.com/v1/tracks/6EYwUarLDfsZ...
# 5096  https://api.spotify.com/v1/tracks/7seTcUFOhn5c...
# 5097  https://api.spotify.com/v1/tracks/5O2P9iiztwho...
# 5098  https://api.spotify.com/v1/tracks/5lFDtgWsjRJu...
# 5099  https://api.spotify.com/v1/tracks/6rMwYjoFvxKi...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0SRk...      138867
# 1     https://api.spotify.com/v1/audio-analysis/6b6I...      160280
# 2     https://api.spotify.com/v1/audio-analysis/2PzU...      222813
# 3     https://api.spotify.com/v1/audio-analysis/36ck...      155960
# 4     https://api.spotify.com/v1/audio-analysis/6Aey...      226453
# ...                                                 ...         ...
# 5095  https://api.spotify.com/v1/audio-analysis/6EYw...      210756
# 5096  https://api.spotify.com/v1/audio-analysis/7seT...      214726
# 5097  https://api.spotify.com/v1/audio-analysis/5O2P...      226600
# 5098  https://api.spotify.com/v1/audio-analysis/5lFD...      170638
# 5099  https://api.spotify.com/v1/audio-analysis/6rMw...      256560
#
#      time_signature error
# 0                 4   NaN
# 1                 4   NaN
# 2                 4   NaN
# 3                 4   NaN
# 4                 4   NaN
# ...             ...   ...
# 5095              4   NaN
# 5096              4   NaN
# 5097              4   NaN
# 5098              4   NaN
# 5099              4   NaN
#
# [5100 rows x 19 columns]

# %%
print("Missing songs: ", df_tracks.loc[df_tracks.uri==""].shape[0])
# Out:
# Missing songs:  63

# %%
missing_songs=df.iloc[df_tracks.loc[df_tracks.uri==""].index]

# %%
missing_songs.artist_song2.to_dict()
# Out:
# {199: 'wilson pickett 6345789 souls ville usa',
#  278: 'keith 986',
#  291: 'bill cosby little ole man uptight everything s alright',
#  374: 'stevie wonder shoo be doo be doodad ay',
#  602: 'carole king its too late i feel the earth move',
#  625: 'murray head  the trindad singers superstar',
#  633: 'daddy dewdrop chic kaboom dont ya jes love it',
#  650: 'the osmonds yoyo',
#  659: 'paul mccartney another day oh woman oh why',
#  663: '8th day she s not just another woman',
#  699: 'perry como somos novi os its impossible',
#  837: 'bobby boris pickett and the cryptkickers monster mash',
#  885: 'blue ridge rangers jamb a lay a on the bayou',
#  1020: 'van mccoy  the soul city symphony the hustle',
#  1081: 'al green s halala make me happy',
#  1092: 'neil sedaka  elton john bad blood',
#  1099: 'discotex and the sexolettes get dancin',
#  1109: 'walter murphy  the big apple band a fifth of beethoven',
#  1167: 'wing and a prayer fife and drum corps baby face',
#  1270: 'meco star wars theme can tina band',
#  1272: 'lord david dundas jeans on',
#  1299: 'cj  company devils gun',
#  1476: 'linda ronstadt ooo baby baby',
#  1510: 'rupert holmes escape the pi na cola da song',
#  1681: 'john schneider its now or never',
#  1695: 'gary wright really wanna know you',
#  1741: 'buckner  garcia pacman fever',
#  1796: 'greg guidry go in down',
#  1968: 'irene cara breakdance',
#  2244: 'michael jackson with siedah garrett i just cant stop loving you',
#  2361: 'gloria estefan and miami sound machine 123',
#  2408: 'will to power baby i love your way free bird medley',
#  2513: 'paula abdul and the wild pair opposites attract',
#  2568: 'tyler collins girls nite out',
#  2594: 'ame lorain whole wide world',
#  2595: 'm"otley cr"ue without you',
#  2602: 'cc music factory gonna make you sweat everybody dance now',
#  2607: 'hifive i like the way the kissing game',
#  2634: 'cc music factory here we go',
#  2650: 'cc music factory things that make you go hmmm',
#  2913: 'saltnpepa and en vogue what ta man',
#  2915: 'mariah carey without you never forget you',
#  3100: "los del r'io mac arena bayside boys mix",
#  3114: 'gin blossoms follow you down til i hear it from you',
#  3116: '2pac how do u want it california love',
#  3128: 'alanis morissette you learn you oughta know',
#  3137: 'monica before you walk out of my life like this and like that',
#  3145: 'monica why i love you so much a in t nobody',
#  3165: 'adam clayton and larry mullen theme from mission impossible',
#  3201: 'jewel foolish games you were meant for me',
#  3258: 'toni braxton i dont want to i love me some him',
#  3267: 'brock and the bizz my baby daddy',
#  3281: "los del r'io mac arena bayside boys mix",
#  3347: 'sylke fyne romeo and juliet',
#  3348: "m'ya and sisqo its all about me",
#  3386: 'jewel foolish games you were meant for me',
#  3591: 'kevon edmonds 247',
#  3877: 'erykah badu love of my life an ode to hiphop',
#  4092: 'jayz and linkin park numb encore',
#  4274: 'ti big shit pop pin do it',
#  4461: 'jayz and alicia keys empire state of mind',
#  4520: 'jayz and alicia keys empire state of mind',
#  4547: 'allen kriskris allen live like were dying'}

# %%
#Manually edit song titles that could not be found
songs_edit={199: 'wilson pickett 6345789 souls ville usa',
 278: 'keith 98.6',
 291: 'bill cosby little old man',
 374: 'stevie wonder shoo be doo',
 602: 'carole king its too late',
 625: 'murray head superstar',
 633: 'daddy dewdrop chick a boom',
 650: 'the osmonds yo yo',
 659: 'paul mccartney another day',
 663: '8th day she s not just another woman',
 699: 'perry como its impossible',
 837: 'bobby boris pickett monster mash',
 885: 'blue ridge rangers jambalaya',
 1020: 'van mccoy the hustle',
 1081: 'al green make me happy',
 1092: 'neil sedaka bad blood',
 1099: 'discotex and the sexolettes get dancin',
 1109: 'walter murphy fifth of beethoven',
 1167: 'wing and a prayer fife and drum corps baby face',
 1270: 'meco star wars theme',
 1272: 'david dundas jeans on',
 1299: 'cj  company devils gun',
 1476: 'linda ronstadt ooh baby baby',
 1510: 'rupert holmes escape',
 1681: 'john schneider its now or never',
 1695: 'gary wright really want to know you',
 1741: 'buckner  garcia pac man fever',
 1796: 'greg guidry going down',
 1968: 'irene cara brea kdance',
 2244: 'michael jackson i just cant stop loving you',
 2361: 'gloria estefan sound machine 1 2 3',
 2408: 'will to power baby i love your way',
 2513: 'paula abdul opposites attract',
 2568: 'tyler collins girls nite out',
 2594: 'ame lorain whole wide world',
 2595: 'motley crue without you',
 2602: 'cc music factory gonna make you sweat',
 2607: 'hifive i like the way',
 2634: 'cc music factory here we go',
 2650: 'cc music factory things that make you go hmmm',
 2913: 'saltnpepa whatta man',
 2915: 'mariah carey without you',
 3100: "los del rio macarena",
 3114: 'gin blossoms follow you down',
 3116: '2pac california love',
 3128: 'alanis morissette you learn',
 3137: 'monica before you walk out of my life',
 3145: 'monica why i love you so much',
 3165: 'adam clayton mission impossible',
 3201: 'jewel foolish games you were meant for me',
 3258: 'toni braxton i dont want to',
 3267: 'brock and the bizz my baby daddy',
 3281: "los del rio macarena",
 3347: 'sylke fyne romeo juliet',
 3348: "mya sisqo its all about me",
 3386: 'jewel foolish games',
 3591: 'kevon edmonds 24-7',
 3877: 'erykah badu love of my life',
 4092: 'jayz numb encore',
 4274: 'ti big shit poppin',
 4461: 'jayz empire state of mind',
 4520: 'jayz empire state of mind',
 4547: 'kris allen live like were dying'}

# %%
#get musical features of edited songnames

missing_tracks={}
for k,v in notebook.tqdm(songs_edit.items()):
    try:
            # Get the track URI (a unique ID) corresponding to track
        track_uri = sp.search(v)['tracks']['items'][0]['uri']
        track_id=track_uri.replace("spotify:track:", "")
            #get artist corresponding to track
        artist=sp.search(v)['tracks']['items'][0]['artists'][0]['name']
        r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)
        values=r.json()
        missing_tracks[k]=values
    except:
        pass
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=63.0), HTML(value='')))

# %%
df_missing_tracks=pd.DataFrame.from_dict(missing_tracks).T
df_missing_tracks.shape
# Out:
# (47, 18)

# %%
df_tracks.shape
# Out:
# (5100, 19)

# %%
#drop missings from df_tracks and append df_missing_tracks
df_tracks_2=df_tracks.loc[df_tracks.uri!='']

# %%
df_alltracks=df_tracks_2.append(df_missing_tracks)

# %%
df_alltracks.shape
# Out:
# (5084, 19)

# %%
df_alltracks.sort_index().tail()
# Out:
#      danceability energy key loudness mode speechiness acousticness  \
# 5095        0.608  0.628   8   -6.968    1       0.106        0.212
# 5096        0.706  0.572   8   -5.799    0      0.0326       0.0262
# 5097        0.672   0.52   8   -7.747    1      0.0353        0.859
# 5098        0.893   0.48   1   -3.728    0       0.356      0.00855
# 5099        0.673  0.859  11   -3.007    0       0.056      0.00426
#
#      instrumentalness liveness valence    tempo            type  \
# 5095                0   0.0727   0.587  180.163  audio_features
# 5096                0    0.585   0.574  139.982  audio_features
# 5097                0    0.115    0.37  120.001  audio_features
# 5098                0    0.116   0.382   86.976  audio_features
# 5099            0.015    0.128   0.111  127.978  audio_features
#
#                           id                                   uri  \
# 5095  6EYwUarLDfsZ0BMD3IYETF  spotify:track:6EYwUarLDfsZ0BMD3IYETF
# 5096  7seTcUFOhn5caSDbiSfsp0  spotify:track:7seTcUFOhn5caSDbiSfsp0
# 5097  5O2P9iiztwhomNh8xkR9lJ  spotify:track:5O2P9iiztwhomNh8xkR9lJ
# 5098  5lFDtgWsjRJu8fPOAyJIAK  spotify:track:5lFDtgWsjRJu8fPOAyJIAK
# 5099  6rMwYjoFvxKiaEH4If8ZpZ  spotify:track:6rMwYjoFvxKiaEH4If8ZpZ
#
#                                              track_href  \
# 5095  https://api.spotify.com/v1/tracks/6EYwUarLDfsZ...
# 5096  https://api.spotify.com/v1/tracks/7seTcUFOhn5c...
# 5097  https://api.spotify.com/v1/tracks/5O2P9iiztwho...
# 5098  https://api.spotify.com/v1/tracks/5lFDtgWsjRJu...
# 5099  https://api.spotify.com/v1/tracks/6rMwYjoFvxKi...
#
#                                            analysis_url duration_ms  \
# 5095  https://api.spotify.com/v1/audio-analysis/6EYw...      210756
# 5096  https://api.spotify.com/v1/audio-analysis/7seT...      214726
# 5097  https://api.spotify.com/v1/audio-analysis/5O2P...      226600
# 5098  https://api.spotify.com/v1/audio-analysis/5lFD...      170638
# 5099  https://api.spotify.com/v1/audio-analysis/6rMw...      256560
#
#      time_signature error
# 5095              4   NaN
# 5096              4   NaN
# 5097              4   NaN
# 5098              4   NaN
# 5099              4   NaN

# %% [markdown]
# 16 songs had to be dropped as musical features could not be identified in the Spotify API.

# %%
#merge track feature dataframe with song title and rank dataframe
df_music=df.join(df_alltracks)
df_music
# Out:
#       Rank                                      Song  \
# 0        1                               wooly bully
# 1        2  i cant help myself sugar pie honey bunch
# 2        3                i cant get no satisfaction
# 3        4                       you were on my mind
# 4        5              youve lost that lovin feelin
# ...    ...                                       ...
# 5095    96                                 el perdon
# 5096    97                                 she knows
# 5097    98                             night changes
# 5098    99                              back to back
# 5099   100                     how deep is your love
#
#                               Artist  Year  \
# 0      sam the sham and the pharaohs  1965
# 1                          four tops  1965
# 2                 the rolling stones  1965
# 3                            we five  1965
# 4             the righteous brothers  1965
# ...                              ...   ...
# 5095  nicky jam and enrique iglesias  2015
# 5096          neyo featuring juicy j  2015
# 5097                   one direction  2015
# 5098                           drake  2015
# 5099     calvin harris and disciples  2015
#
#                                                  Lyrics  Source  \
# 0     sam the sham miscellaneous wooly bully wooly b...     3.0
# 1      sugar pie honey bunch you know that i love yo...     1.0
# 2                                                           1.0
# 3      when i woke up this morning you were on my mi...     1.0
# 4      you never close your eyes anymore when i kiss...     1.0
# ...                                                 ...     ...
# 5095  enrique iglesias dime si es verdad me dijeron ...     3.0
# 5096                                                NaN     NaN
# 5097   going out tonight changes into something red ...     1.0
# 5098   oh man oh man oh man not againyeah i learned ...     1.0
# 5099   i want you to breathe me in let me be your ai...     1.0
#
#                        Artists clean  \
# 0      sam the sham and the pharaohs
# 1                          four tops
# 2                 the rolling stones
# 3                            we five
# 4             the righteous brothers
# ...                              ...
# 5095  nicky jam and enrique iglesias
# 5096                            neyo
# 5097                   one direction
# 5098                           drake
# 5099     calvin harris and disciples
#
#                                            artist_song1  \
# 0             sam the sham and the pharaohs wooly bully
# 1     four tops i cant help myself sugar pie honey b...
# 2         the rolling stones i cant get no satisfaction
# 3                           we five you were on my mind
# 4     the righteous brothers youve lost that lovin f...
# ...                                                 ...
# 5095           nicky jam and enrique iglesias el perdon
# 5096                                     neyo she knows
# 5097                        one direction night changes
# 5098                                 drake back to back
# 5099  calvin harris and disciples how deep is your love
#
#                                    songs_clean  \
# 0                                  wooly bully
# 1     i cant help myself sugar pie honey bunch
# 2                   i cant get no satisfaction
# 3                          you were on my mind
# 4               you ve lost that lovin feel in
# ...                                        ...
# 5095                                el per don
# 5096                                 she knows
# 5097                             night changes
# 5098                              back to back
# 5099                     how deep is your love
#
#                                            artist_song2  ... valence    tempo  \
# 0             sam the sham and the pharaohs wooly bully  ...   0.904  140.978
# 1     four tops i cant help myself sugar pie honey b...  ...   0.971  127.935
# 2         the rolling stones i cant get no satisfaction  ...   0.931  136.302
# 3                           we five you were on my mind  ...   0.645  143.259
# 4     the righteous brothers you ve lost that lovin ...  ...   0.376   94.791
# ...                                                 ...  ...     ...      ...
# 5095          nicky jam and enrique iglesias el per don  ...   0.587  180.163
# 5096                                     neyo she knows  ...   0.574  139.982
# 5097                        one direction night changes  ...    0.37  120.001
# 5098                                 drake back to back  ...   0.382   86.976
# 5099  calvin harris and disciples how deep is your love  ...   0.111  127.978
#
#                 type                      id  \
# 0     audio_features  0SRkuudTEWe2HOloI1Nssq
# 1     audio_features  6b6IMqP565TbtFFZg9iFf3
# 2     audio_features  2PzU4IB8Dr6mxV3lHuaG34
# 3     audio_features  36ckFm0oicmvX8bWEErIHd
# 4     audio_features  6AeyHqzNHJthYJbn0tvJ4b
# ...              ...                     ...
# 5095  audio_features  6EYwUarLDfsZ0BMD3IYETF
# 5096  audio_features  7seTcUFOhn5caSDbiSfsp0
# 5097  audio_features  5O2P9iiztwhomNh8xkR9lJ
# 5098  audio_features  5lFDtgWsjRJu8fPOAyJIAK
# 5099  audio_features  6rMwYjoFvxKiaEH4If8ZpZ
#
#                                        uri  \
# 0     spotify:track:0SRkuudTEWe2HOloI1Nssq
# 1     spotify:track:6b6IMqP565TbtFFZg9iFf3
# 2     spotify:track:2PzU4IB8Dr6mxV3lHuaG34
# 3     spotify:track:36ckFm0oicmvX8bWEErIHd
# 4     spotify:track:6AeyHqzNHJthYJbn0tvJ4b
# ...                                    ...
# 5095  spotify:track:6EYwUarLDfsZ0BMD3IYETF
# 5096  spotify:track:7seTcUFOhn5caSDbiSfsp0
# 5097  spotify:track:5O2P9iiztwhomNh8xkR9lJ
# 5098  spotify:track:5lFDtgWsjRJu8fPOAyJIAK
# 5099  spotify:track:6rMwYjoFvxKiaEH4If8ZpZ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0SRkuudTEWe2...
# 1     https://api.spotify.com/v1/tracks/6b6IMqP565Tb...
# 2     https://api.spotify.com/v1/tracks/2PzU4IB8Dr6m...
# 3     https://api.spotify.com/v1/tracks/36ckFm0oicmv...
# 4     https://api.spotify.com/v1/tracks/6AeyHqzNHJth...
# ...                                                 ...
# 5095  https://api.spotify.com/v1/tracks/6EYwUarLDfsZ...
# 5096  https://api.spotify.com/v1/tracks/7seTcUFOhn5c...
# 5097  https://api.spotify.com/v1/tracks/5O2P9iiztwho...
# 5098  https://api.spotify.com/v1/tracks/5lFDtgWsjRJu...
# 5099  https://api.spotify.com/v1/tracks/6rMwYjoFvxKi...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0SRk...      138867
# 1     https://api.spotify.com/v1/audio-analysis/6b6I...      160280
# 2     https://api.spotify.com/v1/audio-analysis/2PzU...      222813
# 3     https://api.spotify.com/v1/audio-analysis/36ck...      155960
# 4     https://api.spotify.com/v1/audio-analysis/6Aey...      226453
# ...                                                 ...         ...
# 5095  https://api.spotify.com/v1/audio-analysis/6EYw...      210756
# 5096  https://api.spotify.com/v1/audio-analysis/7seT...      214726
# 5097  https://api.spotify.com/v1/audio-analysis/5O2P...      226600
# 5098  https://api.spotify.com/v1/audio-analysis/5lFD...      170638
# 5099  https://api.spotify.com/v1/audio-analysis/6rMw...      256560
#
#      time_signature error
# 0                 4   NaN
# 1                 4   NaN
# 2                 4   NaN
# 3                 4   NaN
# 4                 4   NaN
# ...             ...   ...
# 5095              4   NaN
# 5096              4   NaN
# 5097              4   NaN
# 5098              4   NaN
# 5099              4   NaN
#
# [5100 rows x 29 columns]

# %%
#Save data frame - alternative to CSV: Pandas's to_pickle method
df_music.to_pickle("df_music")
